# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[10,20,30]
plt.plot(x,y)
plt.title("INFORMATION")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
x=np.array([2,3])
y=np.array([20,30])
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'o')
plt.show()

# %% [markdown]
# #BARPLOT
# --

# %%
l=["c","java","python","js"]
stu=[34,65,23,65]
plt.bar(l,stu)
plt.show()

# %% [markdown]
# #HISTOGRAM
# --

# %%
fig,ax = plt.subplots(1,1)
a= np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
ax.hist(a, bins = [0,25,50,75,100])
ax.set_title("histogram of result")
ax.set_xticks([0,25,50,75,100])
ax.set_xlabel('marks')
ax.set_ylabel('no. of students')
plt.show()

# %% [markdown]
# #PIE CHART
# --

# %%
s=[1,2,3,4]
l=["India","china","America","Norway"]
e=[0.2,0,0,0]
c=["#c70039","#ff5733","#c70040","#ff5738"]
plt.pie(s,labels=l,explode=e)
plt.show()

# %% [markdown]
# #SCATTERPLOT
# --

# %%
x=[1,2,3,4]
y=[4,3,2,1]
x1=[10,20,30,40]
y1=[40,30,20,10]
plt.scatter(x,y,label="high",color="r")
plt.scatter(x1,y1,label="low",color="b")
plt.show()
